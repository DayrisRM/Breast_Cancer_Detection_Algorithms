# %% [markdown]
# **Dataset 1995 wdbc**

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.2.0
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
library(psych)

if(!require('readr')) {
    install.packages('readr')
    library('readr')
}
# Out:
# Attaching package: ‘psych’
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha

# %%
ruta <- "wdbc.csv"
df2 <- read.csv(paste("wdbc.csv","", sep=""))
df2$X<-NULL
df2$id<-NULL

# %%
df2
# Out:
#     diagnosis radius_1ean texture_1ean peri1eter_1ean area_1ean s1oothness_1ean
# 1   1         17.990      10.38        122.80         1001.0    0.11840
# 2   1         20.570      17.77        132.90         1326.0    0.08474
# 3   1         19.690      21.25        130.00         1203.0    0.10960
# 4   1         11.420      20.38         77.58          386.1    0.14250
# 5   1         20.290      14.34        135.10         1297.0    0.10030
# 6   1         12.450      15.70         82.57          477.1    0.12780
# 7   1         18.250      19.98        119.60         1040.0    0.09463
# 8   1         13.710      20.83         90.20          577.9    0.11890
# 9   1         13.000      21.82         87.50          519.8    0.12730
# 10  1         12.460      24.04         83.97          475.9    0.11860
# 11  1         16.020      23.24        102.70          797.8    0.08206
# 12  1         15.780      17.89        103.60          781.0    0.09710
# ...

# %%
map_int(df2, function(.x) sum(is.na(.x)))
# Out:
#               diagnosis             radius_1ean            texture_1ean
#                       0                       0                       0
#          peri1eter_1ean               area_1ean         s1oothness_1ean
#                       0                       0                       0
#        co1pactness_1ean          concavity_1ean     concave.points_1ean
#                       0                       0                       0
#           sy11etry_1ean  fractal_di1ension_1ean               radius_se
#                       0                       0                       0
#              texture_se            peri1eter_se                 area_se
#                       0                       0                       0
#           s1oothness_se          co1pactness_se            concavity_se
#                       0                       0                       0
#       concave.points_se             sy11etry_se    fractal_di1ension_se
# ...

# %%
table(df2$diagnosis)
# Out:
#   0   1
# 357 212

# %%
summary(df2)
# Out:
#    diagnosis       radius_1ean      texture_1ean   peri1eter_1ean
#  Min.   :0.0000   Min.   : 6.981   Min.   : 9.71   Min.   : 43.79
#  1st Qu.:0.0000   1st Qu.:11.700   1st Qu.:16.17   1st Qu.: 75.17
#  Median :0.0000   Median :13.370   Median :18.84   Median : 86.24
#  Mean   :0.3726   Mean   :14.127   Mean   :19.29   Mean   : 91.97
#  3rd Qu.:1.0000   3rd Qu.:15.780   3rd Qu.:21.80   3rd Qu.:104.10
#  Max.   :1.0000   Max.   :28.110   Max.   :39.28   Max.   :188.50
#    area_1ean      s1oothness_1ean   co1pactness_1ean  concavity_1ean
#  Min.   : 143.5   Min.   :0.05263   Min.   :0.01938   Min.   :0.00000
#  1st Qu.: 420.3   1st Qu.:0.08637   1st Qu.:0.06492   1st Qu.:0.02956
#  Median : 551.1   Median :0.09587   Median :0.09263   Median :0.06154
#  Mean   : 654.9   Mean   :0.09636   Mean   :0.10434   Mean   :0.08880
#  3rd Qu.: 782.7   3rd Qu.:0.10530   3rd Qu.:0.13040   3rd Qu.:0.13070
#  Max.   :2501.0   Max.   :0.16340   Max.   :0.34540   Max.   :0.42680
# ...

# %%
pairs.panels(df2[1:15], method = "pearson",
hist.col = "#00AFBB",
density = TRUE,
ellipses = TRUE,
scale=20
)
# Out:
# plot without title

# %%
pairs.panels(df2[16:30], method = "pearson",
hist.col = "#00AFBB",
density = TRUE,
ellipses = TRUE,
scale=20
)
# Out:
# plot without title
